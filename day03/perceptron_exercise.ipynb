# %% [markdown]
# # SHAPE AI/ML
# ## Summer 2025 - Day 3
# ## Linear models and the perceptron algorithm

# %% [markdown]
# ### Part 1: Perceptron by hand
#
# Consider the following dataset:
#
# | x1 | x2 | class label |
# | -- | -- | --------- |
# | 2  | 1  | +1        |
# | 1  | -1 | -1        |
# | -1 | -2 | -1        |
# | -2 | 1  | +1        |
#
# On paper, graph the data in 2D.
#
# Start with w1 = 1, w2=0 and b = 0. Draw the corresponding separation boundary.
#
# Then perform the updates of the perceptron algorithm on paper, until convergence. Assume a learning rate of 1. You may want to keep a table of parameters after each iteration.
#
#
#
# ### Part 2: Implementing th perceptron

# %%
import pandas as pd

# %%
data = pd.read_csv("fisher_iris.csv")

# %% [markdown]
# ### Data set: The Iris Flower database
# The Iris flower database is a famous data set often used in data analysis/machine learning courses (and early papers).
#
# It consists of data collected for specimen of three different types of iris flowers.

# %%
data
# Out:
#      class  PetalWidth  PetalLength  SepalWidth  SepalLength
# 0        0           2           14          33           50
# 1        1          24           56          31           67
# 2        1          23           51          31           69
# 3        0           2           10          36           46
# 4        1          20           52          30           65
# ..     ...         ...          ...         ...          ...
# 145      1          20           50          25           57
# 146      2          13           40          23           55
# 147      0           2           17          34           54
# 148      1          24           51          28           58
# 149      0           2           15          37           53
#
# [150 rows x 5 columns]

# %% [markdown]
# Each row represents a flower specimen. The colums are in the following order:
# * class (0: *Iris-Setosa*, 1: *Iris-Versicolour*, 2: *Iris-Virginica*)
# * Petal width in mm
# * Petal length in mm
# * Sepal width in mm
# * Sepal length in mm
#
# <img src="https://raw.githubusercontent.com/cucs-python/public/spring-2023/e1006/lectures/sepal_and_petal.jpeg" width="200px">

# %% [markdown]
# ### Part 2.1: Filter and visualize the dataset
#
# * Create a version of the dataset that only contains setosa and virginica flower (class 0 and class 1). We will use the perceptron algorithm to learn a classifier that can distinguish these two classes.
# Your dataset should also only contain 3 attributes, such as PetalWidth, PetalLength and SepalWidth (so we can visualize the data).
#
# * Visualize the two classes in 3D. Does it look like it's linearly separable?
#
# * Also split the data into a training set (80% = 120 rows) and testing set (20% = 30 rows).

# %% [markdown]
# ### Part 2.2: Implementing the perceptron algorithm
#
# Implement the perceptron algorithm. You may want to use numpy to compute the prediction and the weight updates -- or you could just use Python lists to store the weights and then iterate with a for loop to do the updates.

# %%
import numpy as np

class PerceptronModel:
    
    def __init__(self, dimensions = 3, learning_rate = 0.1): 
        self.bias = 0
        self.weights = np.ones((dimensions,)) 
        self.lr = 0.1
    
    
    def fit(input_data_x, input_data_y, iter_limit = 10):
        """ 
        Train the model on the training data using the perceptron algorithm. 
        Stop after iter_limit iterations if the algorithm hasn't converged yet.
        """
        # you may just want to call your epoch method here. 
        pass 
    

    def epoch(input_data_x, input_data_y):
        """
        Perform ONE epoch of the perceptron algorithm on the dataset. 
        After the epoch, visualize the separation boundary in 3D. 
        """
        pass
    
    
    def predict(new_x):
        """
        Return the output predicted by the model for input new_x, 
        even if new_x has not been seen during training.
        """
        pass
    
    
    def evaluate(test_data_x, test_data_y):
        """
        Run the perceptron on each test data point. Compute the accuaracy (i.e. # correct predictions / # total predictions)
        """
